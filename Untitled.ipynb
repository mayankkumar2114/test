# %%
#Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
#strings must be inside inverted commas for it to be printed
print(books)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(books)
#
# NameError: name 'books' is not defined

# %%
#integer floats also other things does not need to be included in inverted commasabs
print(8)
print(8.9)
print(True)#Boolean
#we can print more than 2 things in one go
print('hello',1,1.3,True)
# Out:
# 8
# 8.9
# True
# hello 1 1.3 True

# %%
print('hello')
print('world')
print('hello',end='-')#by default the python end the print command by the next line so by using the end function we can change the end of the line
print('world')
# Out:
# hello
# world
# hello-world

# %%
#howewer we can also print the string or whatever the thing whch we want to print if the ending 
#of the previous print command is not in the next by simply using the \_nn at the starting of the 
#the thing which we want to pprint
print('hello',end='==')
print('\nworld')
# Out:
# hello==
# world

# %%
#DATATYPES

# %%
#Integer
print(89)
print(1e308)#this is the highest value python supports after this it starts showing infinity
#1*10^308
# Out:
# 89
# 1e+308

# %%
#Decimal/Float
print(9.44)
print(1.7e308)#highest decimal point
# Out:
# 9.44
# 1.7e+308

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('hello')
# Out:
# hello

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List->C->Arrays
print([2,45,6,7,3])
# Out:
# [2, 45, 6, 7, 3]

# %%
#tuple
